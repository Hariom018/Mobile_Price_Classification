# %% [markdown]
# Consider the problem of Mobile Price Classification.
#
# Apply appropriate data pre-processing techniques.
#
# Extract important features.
#
# Apply atleast 3 classification variants.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset1 = pd.read_csv('/content/train (1).csv')

# %%
dataset1.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dataset1.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
dataset1.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
sns.heatmap(dataset1.iloc[:,0:8].corr(),annot = True)
plt.show()

# %%
sns.heatmap(dataset1.iloc[:,8:16].corr(),annot = True)
plt.show()

# %%
sns.heatmap(dataset1.iloc[:,16:22].corr(),annot = True)
plt.show()

# %%
sns.boxplot(dataset1['battery_power'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dataset1['clock_speed'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dataset1['dual_sim'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dataset1['four_g'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dataset1['int_memory'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.boxplot(dataset1['n_cores'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
datset1 = dataset1.drop(['sc_w'],axis =1,inplace = True)

# %%
datset1 = dataset1.drop(['sc_h'],axis =1 , inplace = True)

# %%
datset1 = dataset1.drop(['talk_time'],axis =1,inplace = True)

# %%
datset1 = dataset1.drop(['blue'],axis =1 ,inplace = True)

# %%
datset1 = dataset1.drop(['pc'],axis =1,inplace = True)

# %%
datset1 = dataset1.drop(['m_dep'],axis =1,inplace = True)

# %%
datset1 = dataset1.drop(['fc'],axis =1,inplace = True)

# %%
datset1 = dataset1.drop(['mobile_wt'],axis =1,inplace = True)

# %%
dataset1.describe()
# Out:
#        battery_power  clock_speed     dual_sim       four_g   int_memory  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     1.522250     0.509500     0.521500    32.046500
# std       439.418206     0.816004     0.500035     0.499662    18.145715
# min       501.000000     0.500000     0.000000     0.000000     2.000000
# 25%       851.750000     0.700000     0.000000     0.000000    16.000000
# 50%      1226.000000     1.500000     1.000000     1.000000    32.000000
# 75%      1615.250000     2.200000     1.000000     1.000000    48.000000
# max      1998.000000     3.000000     1.000000     1.000000    64.000000
#
#            n_cores    px_height     px_width          ram      three_g  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      4.520500   645.108000  1251.515500  2124.213000     0.761500
# std       2.287837   443.780811   432.199447  1084.732044     0.426273
# ...

# %%
dataset1.isnull().sum()
# Out:
# battery_power    0
# clock_speed      0
# dual_sim         0
# four_g           0
# int_memory       0
# n_cores          0
# px_height        0
# px_width         0
# ram              0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
X = dataset1.iloc[:,:-1].values
y = dataset1.iloc[:,-1].values

# %%
print(X)
# Out:
# [[8.420e+02 2.200e+00 0.000e+00 ... 0.000e+00 0.000e+00 1.000e+00]
#  [1.021e+03 5.000e-01 1.000e+00 ... 1.000e+00 1.000e+00 0.000e+00]
#  [5.630e+02 5.000e-01 1.000e+00 ... 1.000e+00 1.000e+00 0.000e+00]
#  ...
#  [1.911e+03 9.000e-01 1.000e+00 ... 1.000e+00 1.000e+00 0.000e+00]
#  [1.512e+03 9.000e-01 0.000e+00 ... 1.000e+00 1.000e+00 1.000e+00]
#  [5.100e+02 2.000e+00 1.000e+00 ... 1.000e+00 1.000e+00 1.000e+00]]

# %%
print(y)
# Out:
# [1 2 2 ... 3 0 3]

# %% [markdown]
# Future Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
print(X)
# Out:
# [[-0.90259726  0.83077942 -1.01918398 ... -1.78686097 -1.00601811
#    0.98609664]
#  [-0.49513857 -1.2530642   0.98117712 ...  0.55964063  0.99401789
#   -1.01409939]
#  [-1.5376865  -1.2530642   0.98117712 ...  0.55964063  0.99401789
#   -1.01409939]
#  ...
#  [ 1.53077336 -0.76274805  0.98117712 ...  0.55964063  0.99401789
#   -1.01409939]
#  [ 0.62252745 -0.76274805 -1.01918398 ...  0.55964063  0.99401789
#    0.98609664]
#  [-1.65833069  0.58562134  0.98117712 ...  0.55964063  0.99401789
#    0.98609664]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1000)

from sklearn.linear_model import LogisticRegression
lreg = LogisticRegression()
lreg.fit(X_train, y_train)
y_pred = lreg.predict(X_test)

from sklearn.metrics import confusion_matrix, accuracy_score

accuracy = accuracy_score(y_test, y_pred) * 100
print("Accuracy of the Logistic Regression Model: ",accuracy)
print(y_pred)
# Out:
# Accuracy of the Logistic Regression Model:  95.25
# [3 1 3 2 3 1 1 1 1 3 0 2 2 1 0 3 2 3 1 3 2 2 2 2 3 2 3 1 1 2 2 3 0 3 3 3 0
#  2 1 3 2 0 0 2 3 3 2 2 2 0 0 2 1 0 2 1 3 0 3 0 0 3 1 1 2 0 0 1 0 0 0 2 1 1
#  1 3 3 2 3 0 0 2 1 2 0 1 1 0 3 1 3 0 0 1 2 2 2 0 2 0 1 3 1 3 2 1 0 3 0 3 0
#  0 3 2 0 0 3 0 1 2 1 1 3 0 1 1 3 2 1 3 1 0 2 1 1 1 2 2 0 3 2 3 2 3 3 2 1 0
#  3 2 0 0 1 2 0 1 1 2 0 0 3 2 2 2 3 2 2 2 0 3 2 1 1 1 0 1 3 1 2 1 2 1 2 2 0
#  3 3 1 2 1 2 2 0 1 3 0 0 1 3 1 3 3 0 2 3 0 2 0 1 3 1 1 3 1 2 0 3 0 1 2 1 2
#  3 2 0 2 0 3 3 3 2 3 3 2 3 0 3 1 3 3 3 0 0 0 2 3 0 3 0 2 0 0 1 3 2 3 1 0 2
#  2 1 1 0 2 0 2 2 3 3 3 0 1 3 3 1 0 2 1 0 1 0 1 2 1 3 1 0 3 1 2 1 0 1 3 0 2
#  2 0 1 1 3 2 1 1 3 2 3 3 0 3 1 1 1 3 2 3 3 0 1 3 3 0 2 2 1 0 0 2 0 3 1 0 2
#  2 2 1 0 3 2 2 0 3 2 1 1 0 1 2 1 2 3 2 3 2 1 0 1 3 1 2 3 1 1 0 3 1 0 1 1 0
#  1 3 0 2 0 3 1 1 0 2 2 0 1 3 3 2 2 2 1 3 0 3 1 2 2 0 1 3 0 1 0 1 2 0 1 1 0
#  2 3 2 2 0 0 3 3 0 2 0 0 3 2 3 3 1 0 1 1 0 0 3 2 2 3 2 3 1 1 1 1 1 2 0 0 2
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1000)

from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)

from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)
print(y_pred)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 80.375
# [3 1 3 2 3 1 1 1 1 3 0 2 2 1 0 3 2 3 1 3 2 2 3 2 3 2 3 0 1 2 2 3 0 3 3 3 0
#  2 1 3 2 0 0 1 3 3 1 2 2 0 0 1 1 0 2 1 3 0 3 0 0 3 1 1 2 0 1 0 0 0 0 2 1 1
#  1 3 3 2 3 0 0 2 1 3 0 2 2 0 3 2 3 0 0 1 1 2 2 0 2 0 1 3 1 3 1 1 0 2 0 3 0
#  0 3 2 0 0 3 0 1 3 1 1 3 0 1 0 3 2 1 3 1 0 2 2 1 1 1 2 0 3 2 3 2 3 3 2 1 0
